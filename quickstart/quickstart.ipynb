# %%
from algorithmeai import BlackSwanClassifier

# %%
model = BlackSwanClassifier("train.csv")
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Code Built with hash fb92cf1645d3f0d47be96a05570aac3583cefe9b6387247be808a3a048cd0ca3

# %%
new_model = BlackSwanClassifier("bc0ad6c0d46f32551bda63fb70e6186bdad6cb66bd39958d40a99beee4ae5bde")
# Out:
# # Algorithme.ai : Response Status 200

# %%
new_model.get_auc("backtest.csv")
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Returned auc 0.828 over backtest.csv with hash 5e84f5dd7335385d60b59975d36268197edcca668e780079df75d6f7216c581c
# 0.828

# %%
new_model.improvePrecision()
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Code Improved Precision with hash 67dc930ca844113a2f18416457fd3cd7921659ec9b90210d50b8a6d4d993b49b

# %%
new_model.improveRecall()
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Code Improved Recall with hash a10cafd90ba99dfb526668bf27c83cd946234fe676bdff27fef934d292913159

# %%
new_model.improve()
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Code Improved with hash 6cf0d9efeb4d393de22327993949efbe526539605f5597ea859b7c38babb9351

# %%
new_model.get_auc("backtest.csv")
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Returned auc 0.843 over backtest.csv with hash 9630b7b00c6564de0d1643b322ae9092308e0cb5bdf5f4fc32a6bfdff53435e9
# 0.843

# %%
auc, opt = new_model.get_auc_opt("backtest.csv")
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Returned auc 0.797 with 0.5 optimal threshold over backtest.csv with hash b948c7518fe0759b31988bbe1dd0e4fdd97ab9ed4242a1d453fe56d98eb23daa

# %%
new_model.get_global_feature_importance("backtest.csv")
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Got Global Feature Importance {'CancerHistory': 0.091, 'GeneticRisk': 0.121, 'PhysicalActivity': 0.167, 'Gender': 0.084, 'AlcoholIntake': 0.148, 'Age': 0.156, 'BMI': 0.161, 'Smoking': 0.071} with hash c4c05f87235879d0ec311b0e9c1076a35ece6a637152a4170bf3213811fa08c3
# {'CancerHistory': 0.091,
#  'GeneticRisk': 0.121,
#  'PhysicalActivity': 0.167,
#  'Gender': 0.084,
#  'AlcoholIntake': 0.148,
#  'Age': 0.156,
#  'BMI': 0.161,
#  'Smoking': 0.071}

# %%
new_model.get_confidence("backtest.csv")
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Got confidence {'0': 0.8333333333333334, '1': 0.1111111111111111, '2': 0.0, '3': 0.12, '4': 0.0, '5': 0.9772727272727273, '6': 0.041666666666666664, '7': 0.0, '8': 0.45, '9': 0.0, '500': 0.8461538461538461, '400': 0.5, '401': 0.0, '402': 0.84375, '403': 0.037037037037037035, '404': 1.0, '405': 0.7058823529411765, '406': 0.9523809523809523, '407': 0.7857142857142857, '408': 0.25, '409': 0.09090909090909091, '410': 0.0, '411': 0.14285714285714285, '412': 0.25, '413': 0.029411764705882353, '414': 0.36363636363636365, '415': 0.6666666666666666, '416': 0.8461538461538461, '417': 0.0, '418': 0.09090909090909091, '419': 0.9090909090909091, '420': 0.3333333333333333, '300': 0.3333333333333333, '421': 0.8888888888888888, '301': 0.4, '422': 0.3076923076923077, '302': 0.023809523809523808, '423': 0.10526315789473684, '303': 0.6923076923076923, '424': 0.85, '304': 0.9473684210526315, '425': 0.125, '305': 0.0, '426': 0.1111111111111111, '306': 0.9655172413793104, '427': 0.0, '307': 0.0, '428': 0
# # Algorithme.ai : Got filtered_index [0, 5, 11, 12, 14, 17, 19, 22, 23, 27, 30, 31, 40, 41, 42, 43, 46, 53, 55, 64, 74, 75, 76, 83, 89, 92, 94, 95, 101, 102, 110, 112, 117, 127, 130, 140, 143, 144, 146, 148, 149, 153, 154, 157, 163, 164, 175, 178, 183, 186, 188, 190, 191, 195, 198, 200, 201, 207, 214, 216, 218, 219, 222, 225, 227, 229, 231, 234, 235, 237, 241, 242, 245, 246, 248, 249, 250, 251, 253, 254, 256, 259, 261, 265, 267, 269, 271, 275, 279, 281, 282, 292, 297, 303, 304, 306, 313, 315, 318, 325, 327, 337, 339, 340, 341, 344, 349, 354, 357, 359, 365, 369, 370, 375, 379, 386, 387, 390, 391, 394, 395, 396, 397, 399, 400, 402, 404, 405, 406, 407, 415, 416, 419, 421, 424, 428, 435, 441, 448, 452, 458, 465, 470, 475, 481, 485, 494, 497, 498, 499, 500] for backtest.csv with hash ad8a261aa1532c69d7692609cf4a1dc7dbfef6117cae2b2eaf1534740cafc1ee
# [0,
#  5,
#  11,
#  12,
#  14,
#  17,
#  19,
#  22,
#  23,
#  27,
#  30,
#  31,
#  40,
#  41,
#  42,
#  43,
#  46,
#  53,
#  55,
#  64,
#  74,
#  75,
#  76,
#  83,
#  89,
#  92,
#  94,
#  95,
#  101,
#  102,
#  110,
#  112,
#  117,
#  127,
#  130,
#  140,
#  143,
#  144,
#  146,
#  148,
#  149,
#  153,
#  154,
#  157,
#  163,
#  164,
#  175,
#  178,
#  183,
#  186,
#  188,
#  190,
#  191,
#  195,
#  198,
#  200,
#  201,
#  207,
#  214,
#  216,
#  218,
#  219,
#  222,
#  225,
#  227,
#  229,
#  231,
#  234,
#  235,
#  237,
#  241,
#  242,
#  245,
#  246,
#  248,
#  249,
#  250,
#  251,
#  253,
#  254,
#  256,
#  259,
#  261,
#  265,
#  267,
#  269,
#  271,
#  275,
#  279,
#  281,
#  282,
#  292,
#  297,
#  303,
#  304,
#  306,
#  313,
#  315,
#  318,
#  325,
#  327,
#  337,
#  339,
#  340,
#  341,
#  344,
#  349,
#  354,
#  357,
#  359,
#  365,
#  369,
#  370,
#  375,
#  379,
#  386,
#  387,
#  390,
#  391,
#  394,
#  395,
#  396,
#  397,
#  399,
#  400,
#  402,
#  404,
#  405,
#  406,
#  407,
#  415,
#  416,
#  419,
#  421,
#  424,
#  428,
#  435,
#  441,
#  448,
#  452,
#  458,
#  465,
#  470,
#  475,
#  481,
#  485,
#  494,
#  497,
#  498,
#  499,
#  500]

# %%
population = new_model.make_population("backtest.csv")
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Returned population of size 501 with hash 517c8504095771f6d380deff7fa0284faf9c984e4ce575cabcc6e90740dfc709

# %%
from random import choice

item = choice(population)

# %%
new_model.get_feature_importance(item)
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Got feature importance {'CancerHistory': 0.091, 'GeneticRisk': 0.091, 'PhysicalActivity': 0.159, 'Diagnosis': 0.0, 'Gender': 0.159, 'AlcoholIntake': 0.114, 'Age': 0.205, 'BMI': 0.091, 'Smoking': 0.091} for item {'CancerHistory': 0.0, 'GeneticRisk': 1.0, 'PhysicalActivity': 3.429665197, 'Diagnosis': 0.0, 'Gender': 0.0, 'AlcoholIntake': 3.774362645, 'Age': 46.0, 'BMI': 25.9415332, 'Smoking': 0.0} with hash ae6aae9b99af5fdd20d072e29a3cc6f4026f6e9fea0ac53214fd2af57357b3e0
# {'CancerHistory': 0.091,
#  'GeneticRisk': 0.091,
#  'PhysicalActivity': 0.159,
#  'Diagnosis': 0.0,
#  'Gender': 0.159,
#  'AlcoholIntake': 0.114,
#  'Age': 0.205,
#  'BMI': 0.091,
#  'Smoking': 0.091}

# %%
new_model.get_item_confidence(item)
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Got confidence 0.0 for item {'CancerHistory': 0.0, 'GeneticRisk': 1.0, 'PhysicalActivity': 3.429665197, 'Diagnosis': 0.0, 'Gender': 0.0, 'AlcoholIntake': 3.774362645, 'Age': 46.0, 'BMI': 25.9415332, 'Smoking': 0.0} with hash ae6aae9b99af5fdd20d072e29a3cc6f4026f6e9fea0ac53214fd2af57357b3e0
# 0.0

# %%
new_model.get_audit(item)
# Out:
# # Algorithme.ai : Response Status 200
# # Algorithme.ai : Got audit {'lookalikes_csv': 'algorithme,Diagnosis,Age,Gender,BMI,Smoking,GeneticRisk,PhysicalActivity,AlcoholIntake,CancerHistory\n1,0.0,35.0,0.0,23.69853529,0.0,1.0,3.20567586,1.924793613,0.0\n1,0.0,28.0,0.0,30.90240116,0.0,1.0,2.267586174,4.150163418,0.0\n1,0.0,56.0,0.0,21.54264209,0.0,0.0,2.011752323,3.60133962,0.0\n1,0.0,50.0,0.0,26.24349606,1.0,1.0,7.714733449,3.782692917,0.0\n1,0.0,73.0,0.0,37.15489451,0.0,0.0,3.855525015,3.402915465,0.0\n1,0.0,44.0,1.0,26.2809836,0.0,0.0,2.706836043,2.925973927,0.0\n1,0.0,42.0,0.0,22.59866003,0.0,2.0,3.093685621,4.979011839,0.0\n1,0.0,31.0,0.0,28.66743532,1.0,1.0,3.565589212,3.52748326,0.0', 'datapoint': {'CancerHistory': 0.0, 'GeneticRisk': 1.0, 'PhysicalActivity': 3.429665197, 'Diagnosis': 0.0, 'Gender': 0.0, 'AlcoholIntake': 3.774362645, 'Age': 46.0, 'BMI': 25.9415332, 'Smoking': 0.0}, 'confidence_percentage': 0.0, 'feature_importance': {'CancerHistory': 0.091, 'GeneticRisk': 0.091, 'PhysicalActivity': 0.159, 'Gender': 0.159, 'AlcoholIntake': 0.114, 'Age': 0.205, 'Smoking': 0.091, 'BMI': 0.091}} for {'CancerHistory': 0.0, 'GeneticRisk': 1.0, 'PhysicalActivity': 3.429665197, 'Diagnosis': 0.0, 'Gender': 0.0, 'AlcoholIntake': 3.774362645, 'Age': 46.0, 'BMI': 25.9415332, 'Smoking': 0.0} with hash 2a9b71c39d6629c03df79752fe2fab07eed2835ef08337fe320568e2b70de31f
# {'lookalikes_csv': 'algorithme,Diagnosis,Age,Gender,BMI,Smoking,GeneticRisk,PhysicalActivity,AlcoholIntake,CancerHistory\n1,0.0,35.0,0.0,23.69853529,0.0,1.0,3.20567586,1.924793613,0.0\n1,0.0,28.0,0.0,30.90240116,0.0,1.0,2.267586174,4.150163418,0.0\n1,0.0,56.0,0.0,21.54264209,0.0,0.0,2.011752323,3.60133962,0.0\n1,0.0,50.0,0.0,26.24349606,1.0,1.0,7.714733449,3.782692917,0.0\n1,0.0,73.0,0.0,37.15489451,0.0,0.0,3.855525015,3.402915465,0.0\n1,0.0,44.0,1.0,26.2809836,0.0,0.0,2.706836043,2.925973927,0.0\n1,0.0,42.0,0.0,22.59866003,0.0,2.0,3.093685621,4.979011839,0.0\n1,0.0,31.0,0.0,28.66743532,1.0,1.0,3.565589212,3.52748326,0.0',
#  'datapoint': {'CancerHistory': 0.0,
#   'GeneticRisk': 1.0,
#   'PhysicalActivity': 3.429665197,
#   'Diagnosis': 0.0,
#   'Gender': 0.0,
#   'AlcoholIntake': 3.774362645,
#   'Age': 46.0,
#   'BMI': 25.9415332,
#   'Smoking': 0.0},
#  'confidence_percentage': 0.0,
#  'feature_importance': {'CancerHistory': 0.091,
#   'GeneticRisk': 0.091,
#   'PhysicalActivity': 0.159,
#   'Gender': 0.159,
#   'AlcoholIntake': 0.114,
#   'Age': 0.205,
#   'Smoking': 0.091,
#   'BMI': 0.091}}

# %%
new_model.to_json("blackswan-api.json")
# Out:
# # Algorithme.ai : Safely saved at blackswan-api.json

# %%
final_model = BlackSwanClassifier("blackswan-api.json")

# %%
print(final_model.log)
# Out:
# ###########################################################################
# #                                                                         #
# #   Algorithme.ai : proprietary technology developed on August 2025       #
# #                                                                         #
# #        author : Charles Dana   product : BlackSwanClassifier            #
# #                                                                         #
# ###########################################################################
# # Analysis train columns ['Age', 'Gender', 'BMI', 'Smoking', 'GeneticRisk', 'PhysicalActivity', 'AlcoholIntake', 'CancerHistory']
# # Analysis header ['Diagnosis', 'Age', 'Gender', 'BMI', 'Smoking', 'GeneticRisk', 'PhysicalActivity', 'AlcoholIntake', 'CancerHistory']
# # Algorithme.ai will perform the BlackSwanClassifier analysis over the [Diagnosis] boolean field, derived from:
# #	[Age] numeric field
# #	[Gender] numeric field
# #	[BMI] numeric field
# #	[Smoking] numeric field
# #	[GeneticRisk] numeric field
# #	[PhysicalActivity] numeric field
# #	[AlcoholIntake] numeric field
# #	[CancerHistory] numeric field
# # Analysis datatypes ['B', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N']
# # Remainder: 6.7s.
# # Remainder: 4.03s.
# # Remainder: 6.6s.
# # Remainder: 3.33s.
# # Remainder: 3.26s.
# # Remainder: 1.56s.
# # Remainder: 1.23s.
# # Remainder: 0.22s.
# # Algorithme.ai : Sucessful BlackSwan build after: 5.45s
# # Algorithme.ai : BlackSwan performed Confidence over /tmp/test.csv with average confidence 0.31673055660053356
# # Algorithme.ai BlackSwan performed an AUC of 0.828 over /tmp/test.csv
# # Remainder: 0.28s.
# # Algorithme.ai : Improved BlackSwan model in: 0.72s
# # Algorithme.ai : Improved BlackSwan model in: 0.61s
# # Remainder: 1.58s.
# # Remainder: 0.24s.
# # Algorithme.ai : Improved BlackSwan model in: 1.38s
# # Algorithme.ai : BlackSwan performed Confidence over /tmp/test.csv with average confidence 0.3198141389709307
# # Algorithme.ai BlackSwan performed an AUC of 0.843 over /tmp/test.csv
# # Algorithme.ai : BlackSwan performed Confidence over /tmp/test.csv with average confidence 0.3198141389709307
# # Algorithme.ai BlackSwan performed an AUC of 0.797 with optimal threshold 0.5 over /tmp/test.csv
# # Algorithme.ai BlackSwan performed global feature importance {'Age': 0.156, 'Gender': 0.084, 'BMI': 0.161, 'Smoking': 0.071, 'GeneticRisk': 0.121, 'PhysicalActivity': 0.167, 'AlcoholIntake': 0.148, 'CancerHistory': 0.091} over /tmp/test.csv
# # Algorithme.ai : BlackSwan performed Confidence over /tmp/test.csv with average confidence 0.3198141389709307
# # Algorithme.ai : BlackSwan performed Confidence over /tmp/test.csv with average confidence 0.3198141389709307
# # Algorithme.ai BlackSwan performed feature importance {'Diagnosis': 0.0, 'Age': 0.205, 'Gender': 0.159, 'BMI': 0.091, 'Smoking': 0.091, 'GeneticRisk': 0.091, 'PhysicalActivity': 0.159, 'AlcoholIntake': 0.114, 'CancerHistory': 0.091} over {'CancerHistory': 0.0, 'GeneticRisk': 1.0, 'PhysicalActivity': 3.429665197, 'Diagnosis': 0.0, 'Gender': 0.0, 'AlcoholIntake': 3.774362645, 'Age': 46.0, 'BMI': 25.9415332, 'Smoking': 0.0}
# # Algorithme.ai : Audit for Datapoint
# {
#   "datapoint": {
#     "CancerHistory": 0.0,
#     "GeneticRisk": 1.0,
#     "PhysicalActivity": 3.429665197,
#     "Diagnosis": 0.0,
#     "Gender": 0.0,
#     "AlcoholIntake": 3.774362645,
#     "Age": 46.0,
#     "BMI": 25.9415332,
#     "Smoking": 0.0
#   },
#   "confidence_percentage": 0.0,
#   "feature_importance": {
#     "Age": 0.205,
#     "AlcoholIntake": 0.114,
#     "Gender": 0.159,
#     "Smoking": 0.091,
#     "GeneticRisk": 0.091,
#     "CancerHistory": 0.091,
#     "BMI": 0.091,
#     "PhysicalActivity": 0.159
#   },
#   "lookalikes_csv": "algorithme,Diagnosis,Age,Gender,BMI,Smoking,GeneticRisk,PhysicalActivity,AlcoholIntake,CancerHistory\n1,0.0,35.0,0.0,23.69853529,0.0,1.0,3.20567586,1.924793613,0.0\n1,0.0,28.0,0.0,30.90240116,0.0,1.0,2.267586174,4.150163418,0.0\n1,0.0,56.0,0.0,21.54264209,0.0,0.0,2.011752323,3.60133962,0.0\n1,0.0,50.0,0.0,26.24349606,1.0,1.0,7.714733449,3.782692917,0.0\n1,0.0,73.0,0.0,37.15489451,0.0,0.0,3.855525015,3.402915465,0.0\n1,0.0,44.0,1.0,26.2809836,0.0,0.0,2.706836043,2.925973927,0.0\n1,0.0,42.0,0.0,22.59866003,0.0,2.0,3.093685621,4.979011839,0.0\n1,0.0,31.0,0.0,28.66743532,1.0,1.0,3.565589212,3.52748326,0.0"
# }
